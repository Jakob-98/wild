# %%
import os
import glob
from pathlib import Path
from matplotlib import pyplot as plt

# %%
labelpath = "C:/temp/ena/labels/test/"

# %%
labelfiles = [os.path.split(i)[1] for i in glob.glob(labelpath + '/*.txt', recursive=True)]

# %%
for lf in labelfiles
# Out:
# ['1003.txt',
#  '1005.txt',
#  '101.txt',
#  '1012.txt',
#  '1016.txt',
#  '1017.txt',
#  '1019.txt',
#  '1025.txt',
#  '1026.txt',
#  '103.txt',
#  '1031.txt',
#  '1034.txt',
#  '1035.txt',
#  '1036.txt',
#  '1038.txt',
#  '1045.txt',
#  '1048.txt',
#  '1053.txt',
#  '1057.txt',
#  '1065.txt',
#  '1085.txt',
#  '1091.txt',
#  '1094.txt',
#  '1096.txt',
#  '1097.txt',
#  '1098.txt',
#  '1104.txt',
#  '1114.txt',
#  '1116.txt',
#  '112.txt',
#  '1127.txt',
#  '1128.txt',
#  '1142.txt',
#  '1143.txt',
#  '1147.txt',
#  '1151.txt',
#  '1155.txt',
#  '1158.txt',
#  '1161.txt',
#  '1170.txt',
#  '1172.txt',
#  '1173.txt',
#  '1174.txt',
#  '1176.txt',
#  '1181.txt',
#  '1188.txt',
#  '119.txt',
#  '1190.txt',
#  '1199.txt',
#  '120.txt',
#  '1201.txt',
#  '1203.txt',
#  '1207.txt',
#  '1231.txt',
#  '1234.txt',
#  '1236.txt',
#  '1241.txt',
#  '1243.txt',
#  '1245.txt',
#  '1248.txt',
#  '1261.txt',
#  '1267.txt',
#  '1289.txt',
#  '1300.txt',
#  '1304.txt',
#  '1305.txt',
#  '1321.txt',
# ...
